# %% [markdown]
# # Get the data and imports

# %%
# !wget -nc https://lazyprogrammer.me/course_files/airline_passengers.csv
# Out:
# File 'airline_passengers.csv' already there; not retrieving.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('airline_passengers.csv', index_col='Month', parse_dates=True)
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
# Check if there are any nan values
df.isna().sum()
# Out:
# Passengers    0
# dtype: int64

# %%
# Plot the data to see the trend
df.plot(figsize=(12, 5))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Can observe both a trend and a cyclcical component.

# %% [markdown]
# # Calculate the EWMA

# %%
alpha = 0.2
df['EWMA'] = df['Passengers'].ewm(alpha=alpha, adjust=False).mean() # adjust=False means that we are using the formula for the EWMA
df.plot(figsize=(12, 5))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # Holt-Winters Model

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
# Assign frequency to the data
df.index.freq = 'MS' # MS means Monthly Start (the first day of the month) - this is the default frequency for pandas
df.head()
# Out:
#             Passengers      EWMA
# Month
# 1949-01-01         112  112.0000
# 1949-02-01         118  113.2000
# 1949-03-01         132  116.9600
# 1949-04-01         129  119.3680
# 1949-05-01         121  119.6944

# %%
# Carry out a train-test split with 12 data points and forecasting 
N_test = 12
train = df.iloc[:len(df)-N_test]
test = df.iloc[len(df)-N_test:]
train_index = df.index <= train.index[-1]
test_index = df.index > train.index[-1]

# %% [markdown]
# ## Test additive model

# %%
holt = ExponentialSmoothing(train['Passengers'], trend='add', seasonal='add', seasonal_periods=12)

# %%
results = holt.fit()

# %%
df.loc[train_index, 'Holt'] = results.fittedvalues
df.loc[test_index, 'Holt'] = results.forecast(N_test)

# %%
df.head()
# Out:
#             Passengers      EWMA        Holt
# Month
# 1949-01-01         112  112.0000  111.956738
# 1949-02-01         118  113.2000  120.147181
# 1949-03-01         132  116.9600  134.689236
# 1949-04-01         129  119.3680  131.305335
# 1949-05-01         121  119.6944  124.575980

# %%
df[['Passengers', 'Holt']].plot(figsize=(12, 5))
# Out:
# <Axes: xlabel='Month'>

# %%
def rmse(y, t):
    return np.sqrt(np.mean((y - t)**2))

def mae(y, t):
    return np.mean(np.abs(y - t))

# %%
print(f"RMSE Train: {rmse(train['Passengers'], results.fittedvalues)}")
print(f"RMSE Test: {rmse(test['Passengers'], results.forecast(N_test))}")

print(f"MAE Train: {mae(train['Passengers'], results.fittedvalues)}")
print(f"MAE Test: {mae(test['Passengers'], results.forecast(N_test))}")
# Out:
# RMSE Train: 11.45172395746754
# RMSE Test: 16.46937178496665
# MAE Train: 8.558094039655206
# MAE Test: 11.6577287937585

# %% [markdown]
# ## Test multiplicative model

# %%
holt = ExponentialSmoothing(train['Passengers'], trend='add', seasonal='mul', seasonal_periods=12)
results = holt.fit()

df.loc[train_index, 'Holt'] = results.fittedvalues
df.loc[test_index, 'Holt'] = results.forecast(N_test)

print(f"RMSE Train: {rmse(train['Passengers'], results.fittedvalues)}")
print(f"RMSE Test: {rmse(test['Passengers'], results.forecast(N_test))}")

print(f"MAE Train: {mae(train['Passengers'], results.fittedvalues)}")
print(f"MAE Test: {mae(test['Passengers'], results.forecast(N_test))}")

df[['Passengers', 'Holt']].plot(figsize=(12, 5))
# Out:
# RMSE Train: 9.768003739508687
# RMSE Test: 15.810015075304594
# MAE Train: 7.604222808184425
# MAE Test: 10.302747268552892
# <Axes: xlabel='Month'>

# %%
holt = ExponentialSmoothing(train['Passengers'], trend='mul', seasonal='mul', seasonal_periods=12)
results = holt.fit()

df.loc[train_index, 'Holt'] = results.fittedvalues
df.loc[test_index, 'Holt'] = results.forecast(N_test)

print(f"RMSE Train: {rmse(train['Passengers'], results.fittedvalues)}")
print(f"RMSE Test: {rmse(test['Passengers'], results.forecast(N_test))}")

print(f"MAE Train: {mae(train['Passengers'], results.fittedvalues)}")
print(f"MAE Test: {mae(test['Passengers'], results.forecast(N_test))}")

df[['Passengers', 'Holt']].plot(figsize=(12, 5))
# Out:
# RMSE Train: 9.617924836513064
# RMSE Test: 25.810661576535814
# MAE Train: 7.112423017573626
# MAE Test: 20.848507044926055
# /Users/andreiroibu/opt/anaconda3/envs/AIforFinancialEngineering/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# <Axes: xlabel='Month'>

# %%
holt = ExponentialSmoothing(train['Passengers'], trend='mul', seasonal='add', seasonal_periods=12)
results = holt.fit()

df.loc[train_index, 'Holt'] = results.fittedvalues
df.loc[test_index, 'Holt'] = results.forecast(N_test)

print(f"RMSE Train: {rmse(train['Passengers'], results.fittedvalues)}")
print(f"RMSE Test: {rmse(test['Passengers'], results.forecast(N_test))}")

print(f"MAE Train: {mae(train['Passengers'], results.fittedvalues)}")
print(f"MAE Test: {mae(test['Passengers'], results.forecast(N_test))}")

df[['Passengers', 'Holt']].plot(figsize=(12, 5))
# Out:
# RMSE Train: 11.45172395746754
# RMSE Test: 16.46937178496665
# MAE Train: 8.558094039655206
# MAE Test: 11.6577287937585
# /Users/andreiroibu/opt/anaconda3/envs/AIforFinancialEngineering/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# <Axes: xlabel='Month'>
